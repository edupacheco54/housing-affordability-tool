# %%
import pandas as pd
import censusdata

# %%
zvhi_df = pd.read_csv("../data/raw/Zip_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")
zvhi_df.sample(5)
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State       City  \
# 3674      91682      3714       77033        zip        TX    TX    Houston
# 2899      84755      2932       61008        zip        IL    IL  Belvidere
# 22818     83006     24037       56673        zip        MN    MN  Roosevelt
# 22629     87051     23799       66033        zip        KS    KS    Greeley
# 9580      69418      9703       27569        zip        NC    NC  Princeton
#
#                                       Metro       CountyName   2000-01-31  \
# 3674   Houston-The Woodlands-Sugar Land, TX    Harris County  59455.84437
# 2899                           Rockford, IL     Boone County          NaN
# 22818                                   NaN    Roseau County          NaN
# 22629                            Ottawa, KS  Anderson County          NaN
# 9580                       Raleigh-Cary, NC  Johnston County          NaN
#
# ...

# %%
zori_df = pd.read_csv("../data/raw/Zip_zori_uc_sfrcondomfr_sm_month.csv")
zori_df.sample(5)
# Out:
#       RegionID  SizeRank  RegionName RegionType StateName State        City  \
# 6638     63955      9223       15224        zip        PA    PA  Pittsburgh
# 5232     90042      6106       73501        zip        OK    OK      Lawton
# 6308     96293      8182       91105        zip        CA    CA    Pasadena
# 1704     91253      1789       76108        zip        TX    TX  Fort Worth
# 1634     95909      1716       89431        zip        NV    NV      Sparks
#
#                                    Metro          CountyName  2015-01-31  ...  \
# 6638                      Pittsburgh, PA    Allegheny County         NaN  ...
# 5232                          Lawton, OK     Comanche County         NaN  ...
# 6308  Los Angeles-Long Beach-Anaheim, CA  Los Angeles County         NaN  ...
# 1704     Dallas-Fort Worth-Arlington, TX      Tarrant County  990.137865  ...
# 1634                            Reno, NV       Washoe County  729.440052  ...
#
# ...

# %%
census_df = censusdata.download('acs5', 2022, censusdata.censusgeo([('zip code tabulation area', '*')]), ['B19013_001E'])
census_df.reset_index(inplace=True)
census_df["zip"] = census_df["index"].astype(str).str.extract(r'(\d{5})')
census_df = census_df[["zip", "B19013_001E"]].rename(columns={"B19013_001E": "median_income"})
census_df["median_income"] = census_df["median_income"].replace(-666666666, pd.NA)

census_df.sample(5)
# Out:
#          zip median_income
# 22685  64158        101189
# 4879   15922          <NA>
# 2982   11702        134602
# 12459  37811         48108
# 14045  43031        100979
